# %% [markdown]
# <a href="https://colab.research.google.com/github/kunal-ppatil/Deep_learning_projects/blob/main/image_data_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget 'data:image/jpeg;base64,...'
# Out:
# --2025-11-20 13:44:47--  ftp://data/image/jpeg;base64,...
#            => ‘jpeg’
# Resolving data (data)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘data’

# %%
# !wget 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQHkmbaje8L3Wm4ZrY4YfcA4aROaTGH6nwfXQ&s'
# Out:
# --2025-11-20 13:47:29--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQHkmbaje8L3Wm4ZrY4YfcA4aROaTGH6nwfXQ&s
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 142.250.98.102, 142.250.98.113, 142.250.98.101, ...
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|142.250.98.102|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6147 (6.0K) [image/jpeg]
# Saving to: ‘images?q=tbn:ANd9GcQHkmbaje8L3Wm4ZrY4YfcA4aROaTGH6nwfXQ&s’
#
# images?q=tbn:ANd9Gc 100%[===================>]   6.00K  --.-KB/s    in 0s
#
# 2025-11-20 13:47:29 (67.0 MB/s) - ‘images?q=tbn:ANd9GcQHkmbaje8L3Wm4ZrY4YfcA4aROaTGH6nwfXQ&s’ saved [6147/6147]

# %%
#importing the image module from matplotlib
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
#loading an image through matplotlib.image module
img = mpimg.imread('/content/images?q=tbn:ANd9GcRMD0_HISeBUAC0eXVyVDCs-EEfhS9j6eWYhQ&s')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (168, 300, 3)

# %%
print(img)
# Out:
# [[[16 19  0]
#   [16 19  0]
#   [16 19  0]
#   ...
#   [20 18  5]
#   [19 17  5]
#   [19 17  5]]
#
#  [[15 18  0]
#   [15 18  0]
#   [15 18  0]
#   ...
#   [19 17  4]
#   [19 17  5]
#   [18 16  4]]
#
#  [[15 18  1]
#   [15 18  1]
#   [15 18  1]
#   ...
#   [18 16  3]
#   [18 16  4]
#   [17 15  3]]
#
#  ...
#
#  [[72 85 32]
#   [67 80 27]
#   [52 65 12]
#   ...
#   [57 69 21]
#   [60 72 26]
#   [62 74 28]]
#
#  [[58 71 17]
#   [57 70 16]
#   [58 71 18]
#   ...
#   [53 65 15]
#   [56 68 20]
#   [57 69 21]]
#
#  [[51 64 10]
#   [58 71 17]
#   [68 81 28]
#   ...
#   [50 63 10]
#   [52 64 16]
#   [54 66 18]]]

# %%
#displaying the image from numpy array
img_plot=plt.imshow(img)
plt.show()

# %%
#resizing the image using pillow library
from PIL import Image

# %%
img=Image.open('/content/images?q=tbn:ANd9GcRMD0_HISeBUAC0eXVyVDCs-EEfhS9j6eWYhQ&s')

# %%
img_resized=img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
img_res=mpimg.imread('/content/dog_image_resized.jpg')
img_res_plot=plt.imshow(img)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
#converting the rgb image to grayscale
import cv2

# %%
img=cv2.imread('/content/images?q=tbn:ANd9GcRMD0_HISeBUAC0eXVyVDCs-EEfhS9j6eWYhQ&s')

# %%
img_gray=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(img_gray)
# Out:
# numpy.ndarray

# %%
img_gray.shape
# Out:
# (168, 300)

# %%
from google.colab.patches import cv2_imshow

# %%
#displaying the image
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=300x168>
